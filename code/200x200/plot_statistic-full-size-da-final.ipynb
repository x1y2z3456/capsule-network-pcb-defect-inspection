# %%
# %run ./plot_statistic-full-size-da-final.py
# Out:
# DenseCapsNet 100 epoch
# Data Record Number: 100
# ResCapsNet 100 epoch
# Data Record Number: 100
# VGGCapsNet 100 epoch
# Data Record Number: 100
# New DenseCapsNet 200 epoch
# Data Record Number: 200
# New CapsNet V3 200 epoch
# Data Record Number: 200
# New CapsNet V3 350 epoch
# Data Record Number: 350

# %%
# %run ./plot_statistic-full-size-no-da-all.py
# Out:
# New Capsnet V3 100 epoch
# Data Record Number: 100
# New Capsnet V3 200 epoch
# Data Record Number: 200
# New Capsnet V3 100 epoch after
# Data Record Number: 100
# DenseNet121 100 epoch
# Data Record Number: 100
# ResNet50 100 epoch
# Data Record Number: 100
# VGG19 100 epoch
# Data Record Number: 100
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py:3081, in Index.get_loc(self, key, method, tolerance)
#    3080 try:
# -> 3081     return self._engine.get_loc(casted_key)
#    3082 except KeyError as err:
#
# File pandas/_libs/index.pyx:70, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:101, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:4554, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...
