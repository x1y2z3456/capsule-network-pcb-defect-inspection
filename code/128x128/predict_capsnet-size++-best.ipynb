# %%
# %run ./predict_capsnet-size++-best.py
# Out:
# New CapsNet v3
# Found 22500 images belonging to 2 classes.
# Trainable Parameters：443,840
# 352/352 [==============================] - 115s 328ms/step
# Accuracy: 97.08%
# Classification Report:
#               precision    recall  f1-score   support
#
#         D000     0.9688    0.9819    0.9753     13175
#         D001     0.9739    0.9553    0.9645      9325
#
#     accuracy                         0.9708     22500
#    macro avg     0.9713    0.9686    0.9699     22500
# weighted avg     0.9709    0.9708    0.9708     22500
#
# Specificity: 98.19%
# Top-1 Error: 2.92%
# Confusion Matrix:
# New CapsNet v3 200 epoch
# Trainable Parameters：443,840
# 352/352 [==============================] - 115s 328ms/step
# Accuracy: 97.68%
# Classification Report:
#               precision    recall  f1-score   support
#
#         D000     0.9768    0.9838    0.9803     13175
#         D001     0.9768    0.9670    0.9719      9325
#
#     accuracy                         0.9768     22500
# ...

# %%
# %run ./plot_statistic-size++.py
# Out:
# New Capsnet V3 100 epoch
# Data Record Number: 100
# New Capsnet V3 200 epoch
# Data Record Number: 200
# New Capsnet V3 100 epoch after
# Data Record Number: 100
# DenseNet121 100 epoch
# Data Record Number: 100
# ResNet50 100 epoch
# Data Record Number: 100
# VGG19 100 epoch
# Data Record Number: 100
