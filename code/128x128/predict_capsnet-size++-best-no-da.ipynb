# %%
# %run ./predict_capsnet-size++-best-no-da.py
# Out:
# New CapsNet v3
# Found 22500 images belonging to 2 classes.
# Trainable Parameters：443,840
# 352/352 [==============================] - 115s 328ms/step
# Accuracy: 97.17%
# Classification Report:
#               precision    recall  f1-score   support
#
#         D000     0.9756    0.9762    0.9759     13175
#         D001     0.9663    0.9655    0.9659      9325
#
#     accuracy                         0.9717     22500
#    macro avg     0.9709    0.9708    0.9709     22500
# weighted avg     0.9717    0.9717    0.9717     22500
#
# Specificity: 97.62%
# Top-1 Error: 2.83%
# Confusion Matrix:
# New CapsNet v3 200 epoch
# Trainable Parameters：443,840
# 352/352 [==============================] - 113s 322ms/step
# Accuracy: 97.44%
# Classification Report:
#               precision    recall  f1-score   support
#
#         D000     0.9748    0.9816    0.9782     13175
#         D001     0.9738    0.9642    0.9690      9325
#
#     accuracy                         0.9744     22500
# ...

# %%
# %run ./plot_statistic-size++-no-da.py
# Out:
# New Capsnet V3 100 epoch
# Data Record Number: 100
# New Capsnet V3 200 epoch
# Data Record Number: 200
# New Capsnet V3 100 epoch after
# Data Record Number: 100
# DenseNet121 100 epoch
# Data Record Number: 100
# ResNet50 100 epoch
# Data Record Number: 100
# VGG19 100 epoch
# Data Record Number: 100
