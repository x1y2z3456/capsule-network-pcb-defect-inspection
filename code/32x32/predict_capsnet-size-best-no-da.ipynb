# %%
# %run ./predict_capsnet-size-best-no-da.py
# Out:
# New CapsNet
# Found 22500 images belonging to 2 classes.
# Trainable Parameters：264,256
# 176/176 [==============================] - 10s 54ms/step
# Accuracy: 91.26%
# Classification Report:
#               precision    recall  f1-score   support
#
#         D000     0.9092    0.9452    0.9268     13175
#         D001     0.9180    0.8666    0.8915      9325
#
#     accuracy                         0.9126     22500
#    macro avg     0.9136    0.9059    0.9092     22500
# weighted avg     0.9128    0.9126    0.9122     22500
#
# Specificity: 94.52%
# Top-1 Error: 8.74%
# Confusion Matrix:
# Origin CapsNet
# Trainable Parameters：5,375,232
# 176/176 [==============================] - 10s 55ms/step
# Accuracy: 75.88%
# Classification Report:
#               precision    recall  f1-score   support
#
#         D000     0.8337    0.7346    0.7811     13175
#         D001     0.6790    0.7930    0.7316      9325
#
#     accuracy                         0.7588     22500
# ...

# %%
# %run ./plot_statistic-size-no-da.py
# Out:
# New Capsnet V1 100 epoch
# Data Record Number: 100
# Origin Capsnet 300 epoch
# Data Record Number: 300
# DenseNet121 100 epoch
# Data Record Number: 100
# ResNet50 100 epoch
# Data Record Number: 100
# VGG19 100 epoch
# Data Record Number: 100
