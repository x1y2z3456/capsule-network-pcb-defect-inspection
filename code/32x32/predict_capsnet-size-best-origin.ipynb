# %%
# %run ./predict_capsnet-size-best-origin.py
# Out:
# Found 22500 images belonging to 2 classes.
# Origin CapsNet
# Trainable Parameters：2,428,032
# 704/704 [==============================] - 15s 21ms/step
# Accuracy: 82.52%
# Classification Report:
#               precision    recall  f1-score   support
#
#         D000     0.8455    0.8584    0.8519     13175
#         D001     0.7956    0.7783    0.7869      9325
#
#     accuracy                         0.8252     22500
#    macro avg     0.8205    0.8184    0.8194     22500
# weighted avg     0.8248    0.8252    0.8250     22500
#
# Specificity: 85.84%
# Top-1 Error: 17.48%
# Confusion Matrix:
# CapsNet+
# Trainable Parameters：2,431,872
# 704/704 [==============================] - 15s 21ms/step
# Accuracy: 84.38%
# Classification Report:
#               precision    recall  f1-score   support
#
#         D000     0.8523    0.8871    0.8693     13175
#         D001     0.8307    0.7827    0.8060      9325
#
#     accuracy                         0.8438     22500
# ...

# %%
# %run ./plot_statistic-size.py
# Out:
# New Capsnet V1 100 epoch
# Data Record Number: 100
# Origin Capsnet 300 epoch
# Data Record Number: 300
# DenseNet121 100 epoch
# Data Record Number: 100
# ResNet50 100 epoch
# Data Record Number: 100
# VGG19 100 epoch
# Data Record Number: 100
