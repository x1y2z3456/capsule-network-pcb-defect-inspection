# %%
# %run ./predict_capsnet-size+-best.py
# Out:
# New CapsNet
# Found 22500 images belonging to 2 classes.
# Trainable Parameters：295,360
# 176/176 [==============================] - 34s 194ms/step
# Accuracy: 95.38%
# Classification Report:
#               precision    recall  f1-score   support
#
#         D000     0.9638    0.9570    0.9604     13175
#         D001     0.9399    0.9493    0.9446      9325
#
#     accuracy                         0.9538     22500
#    macro avg     0.9519    0.9532    0.9525     22500
# weighted avg     0.9539    0.9538    0.9539     22500
#
# Specificity: 95.70%
# Top-1 Error: 4.62%
# Confusion Matrix:
# Origin CapsNet
# Trainable Parameters：5,375,232
# 176/176 [==============================] - 165s 935ms/step
# Accuracy: 75.84%
# Classification Report:
#               precision    recall  f1-score   support
#
#         D000     0.7662    0.8454    0.8039     13175
#         D001     0.7442    0.6356    0.6856      9325
#
#     accuracy                         0.7584     22500
# ...

# %%
# %run ./plot_statistic-size+.py
# Out:
# New Capsnet V2 200 epoch
# Data Record Number: 200
# Origin Capsnet 300 epoch
# Data Record Number: 300
# DenseNet121 100 epoch
# Data Record Number: 100
# ResNet50 100 epoch
# Data Record Number: 100
# VGG19 100 epoch
# Data Record Number: 100
