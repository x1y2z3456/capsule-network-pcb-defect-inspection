# %%
# %run ./predict_capsnet-size+-best-no-da.py
# Out:
# New CapsNet
# Found 22500 images belonging to 2 classes.
# Trainable Parameters：295,360
# 176/176 [==============================] - 10s 58ms/step
# Accuracy: 93.69%
# Classification Report:
#               precision    recall  f1-score   support
#
#         D000     0.9401    0.9529    0.9465     13175
#         D001     0.9322    0.9142    0.9231      9325
#
#     accuracy                         0.9369     22500
#    macro avg     0.9362    0.9336    0.9348     22500
# weighted avg     0.9368    0.9369    0.9368     22500
#
# Specificity: 95.29%
# Top-1 Error: 6.31%
# Confusion Matrix:
# Origin CapsNet
# Trainable Parameters：5,375,232
# 176/176 [==============================] - 10s 59ms/step
# Accuracy: 53.80%
# Classification Report:
#               precision    recall  f1-score   support
#
#         D000     0.5832    0.7396    0.6522     13175
#         D001     0.4077    0.2533    0.3125      9325
#
#     accuracy                         0.5380     22500
# ...

# %%
# %run ./plot_statistic-size+-no-da.py
# Out:
# New Capsnet V2 200 epoch
# Data Record Number: 200
# Origin Capsnet 300 epoch
# Data Record Number: 300
# DenseNet121 100 epoch
# Data Record Number: 100
# ResNet50 100 epoch
# Data Record Number: 100
# VGG19 100 epoch
# Data Record Number: 100
